# %% [markdown]
# ##Unsupervised Learning
#
# Unsupervised learning is much difficult to do because we are not explicitly telling the computer what it is going to predict.
#
# The following exercise we are going to look at what clustering is.

# %%
from IPython.display import IFrame
IFrame('http://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html', 700, 400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="http://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

plt.figure(figsize=(20,10))
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], c=c, label=target_name, s=200)
plt.legend()
plt.title('PCA of IRIS dataset')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.cluster import KMeans
y_pred = KMeans(n_clusters=3, random_state=0).fit_predict(X)

plt.figure(figsize=(20,10))
for c, i, target_name in zip("rgb", [0, 1, 2], range(1, 4)):
    plt.scatter(X_r[y_pred == i, 0], X_r[y_pred == i, 1], c=c, label=target_name, s=200)
plt.legend()
plt.title('KMeans')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)

for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], c=c, label=target_name, s=200)
plt.legend()
plt.title('PCA of IRIS dataset')
    
plt.subplot(122)
for c, i, target_name in zip("rgb", [0, 1, 2], ['cluster 1', 'cluster 2', 'cluster 3']):
    plt.scatter(X_r[y_pred == i, 0], X_r[y_pred == i, 1], c=c, label=target_name, s=200)
    
plt.legend()
plt.title('Kmeans of IRIS dataset')
